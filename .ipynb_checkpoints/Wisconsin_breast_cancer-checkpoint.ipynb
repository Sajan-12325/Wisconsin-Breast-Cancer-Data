# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing and Understanding data

# %%
columns = ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',    "radius_se","texture_se","perimeter_se","area_se","smoothness_se","sompactness_se","concavity_se","concave points_se","symmetry_se","fractal dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal dimension_worst" ]

# %%
'''df = pd.read_csv('wdbc.data', header = None)


df.head()'''
# Out:
# "df = pd.read_csv('wdbc.data', header = None)\n\n\ndf.head()"

# %%
import pandas as pd
import requests

# Load dataset from a local file or URL
columns = ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',    "radius_se","texture_se","perimeter_se","area_se","smoothness_se","sompactness_se","concavity_se","concave points_se","symmetry_se","fractal dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal dimension_worst" ]
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"
df = pd.read_csv(url, header = None, names = columns)


df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.shape  ## Dimensions of the data
# Out:
# (569, 32)

# %%
df.size
# Out:
# 18208

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave_points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# sompactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal dimension_worst    float64
# dtype: object

# %%
df.columns = df.columns.str.replace('sompactness_se', 'compactness_se')
df.columns = df.columns.str.replace('fractal dimension_se', 'fractal_dimension_se')
df.columns = df.columns.str.replace('fractal dimension_worst', 'fractal_dimension_worst')
df.columns = df.columns.str.replace('concave points_se', 'concave_points_se')
df.columns = df.columns.str.replace('concave points_worst', 'concave_points_worst')

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave_points_worst  symmetry_worst  fractal_dimension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
### No null values are present

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df = df.dropna(axis = 1)

# %%
df.duplicated().sum()
## No duplicates either
# Out:
# 0

# %% [markdown]
# ### Creating a Copy DataFrame

# %%
df_copy = df.copy()

# %%
df_copy = df_copy.drop(columns = ['id']) # Removing unwanted columns Once deleted  comment it

# %%
### Converting diagnosis to numerical

# %%
df_copy['diagnosis'] = df_copy['diagnosis'].replace({'M': 1, 'B': 0})

# %%
df_copy['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %% [markdown]
# ###  Finding outliers for each column

# %%
plt.figure(figsize = (12, 12))

total_boxes = len(df_copy.columns)
n_cols = 5  
n_rows = (total_boxes + n_cols - 1) // n_cols

# Create a figure with subplots
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 3))

# Iterate over the categorical columns
for i, col in enumerate(df_copy.columns):
    # Calculate the row and column indices for the current subplot
    row_idx = i // n_cols
    col_idx = i % n_cols

    # Create a boxplot for the current column
    sns.boxplot(data=df_copy, x=col, ax=axs[row_idx, col_idx])

for i in range(total_boxes, n_rows * n_cols):
    row_idx = i // n_cols
    col_idx = i % n_cols
    axs[row_idx, col_idx].axis('off')

# Layout so plots do not overlap
plt.tight_layout()

plt.show()

# %%
sns.boxplot(df_copy['area_mean'])
plt.show()

# %%
sns.boxplot(df_copy['perimeter_mean'])
plt.show()

# %%
sns.boxplot(df_copy['texture_mean'])
plt.show()

# %%
sns.histplot(df['area_mean'])
plt.show()

# %%
plt.figure(figsize = (4, 4))
sns.pairplot(df[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'diagnosis']], hue='diagnosis')
plt.show()
# Out:
# C:\Users\thall\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
"""from collections import Counter

def detect_outliers(train_data,n,features):
    outlier_indices = []
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(train_data[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(train_data[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        outlier_step = 1.5 * IQR
        outlier_list_col = train_data[(train_data[col] < Q1 - outlier_step) | (train_data[col] > Q3 + outlier_step )].index
        outlier_indices.extend(outlier_list_col)
        
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers   

# detect outliers
list_atributes = df.drop('diagnosis',axis=1).columns
Outliers_to_drop = detect_outliers(df,2,list_atributes)
print(len(Outliers_to_drop))"""
# Out:
# "from collections import Counter\n\ndef detect_outliers(train_data,n,features):\n    outlier_indices = []\n    for col in features:\n        # 1st quartile (25%)\n        Q1 = np.percentile(train_data[col], 25)\n        # 3rd quartile (75%)\n        Q3 = np.percentile(train_data[col],75)\n        # Interquartile range (IQR)\n        IQR = Q3 - Q1\n        outlier_step = 1.5 * IQR\n        outlier_list_col = train_data[(train_data[col] < Q1 - outlier_step) | (train_data[col] > Q3 + outlier_step )].index\n        outlier_indices.extend(outlier_list_col)\n        \n    outlier_indices = Counter(outlier_indices)        \n    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )\n    \n    return multiple_outliers   \n\n# detect outliers\nlist_atributes = df.drop('diagnosis',axis=1).columns\nOutliers_to_drop = detect_outliers(df,2,list_atributes)\nprint(len(Outliers_to_drop))"

# %%
df_copy.columns[1:]
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
### Finding Outliers and removing all at once instead of checking column after column, we remove all at the end
def remove_outliers(data_df, features):
    
    mask = pd.Series(True, index = data_df.index)  ## creates a series of True for given index

    for col in features:

        Q1 = data_df[col].quantile(0.25)

        Q3 = data_df[col].quantile(0.75)

        IQR =Q3 - Q1
        
        ## REMOVING OUTLIERS
        col_mask = (data_df[col] >= (Q1 - 1.5 * IQR)) & (data_df[col] <= (Q3 + 1.5 * IQR))
        
        mask = mask & col_mask
        
        
    return data_df[mask]

df_copy = remove_outliers(df_copy, df_copy.columns[1:])  ## Here excluding the target variable 
df_copy.shape
# Out:
# (398, 31)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 398 entries, 6 to 566
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                398 non-null    int64
#  1   radius_mean              398 non-null    float64
#  2   texture_mean             398 non-null    float64
#  3   perimeter_mean           398 non-null    float64
#  4   area_mean                398 non-null    float64
#  5   smoothness_mean          398 non-null    float64
#  6   compactness_mean         398 non-null    float64
#  7   concavity_mean           398 non-null    float64
#  8   concave_points_mean      398 non-null    float64
#  9   symmetry_mean            398 non-null    float64
#  10  fractal_dimension_mean   398 non-null    float64
#  11  radius_se                398 non-null    float64
#  12  texture_se               398 non-null    float64
#  13  perimeter_se             398 non-null    float64
#  14  area_se                  398 non-null    float64
#  15  smoothness_se            398 non-null    float64
#  16  compactness_se           398 non-null    float64
#  17  concavity_se             398 non-null    float64
#  18  concave_points_se        398 non-null    float64
#  19  symmetry_se              398 non-null    float64
#  20  fractal_dimension_se     398 non-null    float64
#  21  radius_worst             398 non-null    float64
#  22  texture_worst            398 non-null    float64
#  23  perimeter_worst          398 non-null    float64
#  24  area_worst               398 non-null    float64
#  25  smoothness_worst         398 non-null    float64
#  26  compactness_worst        398 non-null    float64
#  27  concavity_worst          398 non-null    float64
#  28  concave_points_worst     398 non-null    float64
#  29  symmetry_worst           398 non-null    float64
#  30  fractal_dimension_worst  398 non-null    float64
# dtypes: float64(30), int64(1)
# memory usage: 99.5 KB

# %%
df_copy.isnull().sum() # No null values are inserted
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df_copy.groupby('diagnosis').mean()
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# 0             12.41097     17.638300       79.713733  481.742000
# 1             16.33102     21.161735      106.881429  842.403061
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# 0                 0.091401          0.075990        0.040540
# 1                 0.098997          0.117699        0.121368
#
#            concave_points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# diagnosis                                                              ...
# 0                     0.024900       0.170744                0.061459  ...
# 1                     0.069583       0.182501                0.060451  ...
#
#            radius_worst  texture_worst  perimeter_worst   area_worst  \
# diagnosis
# 0             13.683180      23.314233        88.936567   582.895667
# 1             19.386939      29.035612       128.346327  1174.112245
#
#            smoothness_worst  compactness_worst  concavity_worst  \
# diagnosis
# 0                  0.124096           0.178691         0.158547
# 1                  0.142729           0.312020         0.381512
#
#            concave_points_worst  symmetry_worst  fractal_dimension_worst
# diagnosis
# 0                      0.075607        0.270458                 0.077457
# 1                      0.159780        0.305523                 0.085870
#
# [2 rows x 30 columns]

# %%
df_copy.corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.680705      0.388596        0.695835
# radius_mean               0.680705     1.000000      0.280796        0.998113
# texture_mean              0.388596     0.280796      1.000000        0.285880
# perimeter_mean            0.695835     0.998113      0.285880        1.000000
# area_mean                 0.698005     0.992047      0.288688        0.990235
# smoothness_mean           0.271570     0.055311     -0.046879        0.093196
# compactness_mean          0.514346     0.442360      0.181078        0.492915
# concavity_mean            0.710567     0.658031      0.295111        0.696240
# concave_points_mean       0.752190     0.755607      0.239147        0.785954
# symmetry_mean             0.243588     0.075653      0.051037        0.102371
# fractal_dimension_mean   -0.086631    -0.436397     -0.110214       -0.393736
# radius_se                 0.571842     0.534801      0.290195        0.542837
# texture_se                0.007755    -0.149935      0.474188       -0.144895
# perimeter_se              0.565909     0.530347      0.294101        0.546622
# area_se                   0.703715     0.758127      0.325637        0.763671
# smoothness_se            -0.036030    -0.301325      0.089100       -0.283129
# compactness_se            0.229104     0.165214      0.212798        0.207785
# concavity_se              0.325974     0.265486      0.242464        0.302232
# concave_points_se         0.387972     0.363046      0.198599        0.394612
# symmetry_se              -0.194890    -0.327179      0.011039       -0.318263
# fractal_dimension_se      0.062799    -0.100183      0.095912       -0.063267
# radius_worst              0.761081     0.971286      0.311152        0.972912
# texture_worst             0.437909     0.273847      0.914721        0.280552
# perimeter_worst           0.768194     0.964851      0.316562        0.971558
# area_worst                0.773626     0.957772      0.317755        0.959710
# smoothness_worst          0.396847     0.087209      0.069886        0.121237
# compactness_worst         0.533996     0.416464      0.216026        0.460901
# concavity_worst           0.653300     0.563240      0.274070        0.599672
# concave_points_worst      0.726639     0.682235      0.238186        0.712906
# symmetry_worst            0.347406     0.137655      0.076977        0.160178
# fractal_dimension_worst   0.290821    -0.014583      0.060915        0.027877
#
#                          area_mean  smoothness_mean  compactness_mean  \
# diagnosis                 0.698005         0.271570          0.514346
# radius_mean               0.992047         0.055311          0.442360
# texture_mean              0.288688        -0.046879          0.181078
# perimeter_mean            0.990235         0.093196          0.492915
# area_mean                 1.000000         0.058280          0.428703
# smoothness_mean           0.058280         1.000000          0.675183
# compactness_mean          0.428703         0.675183          1.000000
# concavity_mean            0.664847         0.463982          0.837473
# concave_points_mean       0.758145         0.522678          0.805062
# symmetry_mean             0.077918         0.494062          0.470457
# fractal_dimension_mean   -0.423006         0.614693          0.478338
# radius_se                 0.561732         0.224720          0.384081
# texture_se               -0.132103         0.056968         -0.007041
# perimeter_se              0.554631         0.213312          0.467098
# area_se                   0.786897         0.181729          0.431306
# smoothness_se            -0.260649         0.330804          0.115057
# compactness_se            0.161122         0.240507          0.696339
# concavity_se              0.268137         0.230219          0.637905
# concave_points_se         0.354173         0.378191          0.650383
# symmetry_se              -0.308046         0.077346         -0.031880
# fractal_dimension_se     -0.093091         0.283411          0.511339
# radius_worst              0.969353         0.122928          0.487260
# texture_worst             0.280953         0.020158          0.203987
# perimeter_worst           0.962721         0.146367          0.543912
# area_worst                0.971053         0.125280          0.471562
# smoothness_worst          0.102255         0.803945          0.588434
# compactness_worst         0.400703         0.432375          0.861979
# concavity_worst           0.559618         0.372220          0.780565
# concave_points_worst      0.671695         0.463910          0.784528
# symmetry_worst            0.136700         0.375969          0.424398
# fractal_dimension_worst  -0.014754         0.504310          0.656342
#
#                          concavity_mean  concave_points_mean  symmetry_mean  \
# diagnosis                      0.710567             0.752190       0.243588
# radius_mean                    0.658031             0.755607       0.075653
# texture_mean                   0.295111             0.239147       0.051037
# perimeter_mean                 0.696240             0.785954       0.102371
# area_mean                      0.664847             0.758145       0.077918
# smoothness_mean                0.463982             0.522678       0.494062
# compactness_mean               0.837473             0.805062       0.470457
# concavity_mean                 1.000000             0.930271       0.365858
# concave_points_mean            0.930271             1.000000       0.365482
# symmetry_mean                  0.365858             0.365482       1.000000
# fractal_dimension_mean         0.161284             0.081948       0.320713
# radius_se                      0.514898             0.577415       0.276926
# texture_se                     0.015362            -0.048016       0.070428
# perimeter_se                   0.570050             0.600895       0.283946
# area_se                        0.634078             0.707590       0.225929
# smoothness_se                  0.076744             0.019410       0.152753
# compactness_se                 0.594814             0.434700       0.256796
# concavity_se                   0.714648             0.515534       0.212781
# concave_points_se              0.650606             0.649796       0.268485
# symmetry_se                   -0.099992            -0.148973       0.294551
# fractal_dimension_se           0.358776             0.220363       0.184248
# radius_worst                   0.697135             0.792484       0.128278
# texture_worst                  0.323000             0.272741       0.079260
# perimeter_worst                0.737467             0.816780       0.148892
# area_worst                     0.701045             0.790517       0.128689
# smoothness_worst               0.490384             0.509263       0.381236
# compactness_worst              0.772677             0.692292       0.339391
# concavity_worst                0.904941             0.794996       0.292389
# concave_points_worst           0.861916             0.908179       0.316389
# symmetry_worst                 0.363584             0.360800       0.675715
# fractal_dimension_worst        0.470354             0.381099       0.298244
#
#                          ...  radius_worst  texture_worst  perimeter_worst  \
# diagnosis                ...      0.761081       0.437909         0.768194
# radius_mean              ...      0.971286       0.273847         0.964851
# texture_mean             ...      0.311152       0.914721         0.316562
# perimeter_mean           ...      0.972912       0.280552         0.971558
# area_mean                ...      0.969353       0.280953         0.962721
# smoothness_mean          ...      0.122928       0.020158         0.146367
# compactness_mean         ...      0.487260       0.203987         0.543912
# concavity_mean           ...      0.697135       0.323000         0.737467
# concave_points_mean      ...      0.792484       0.272741         0.816780
# symmetry_mean            ...      0.128278       0.079260         0.148892
# fractal_dimension_mean   ...     -0.366713      -0.080477        -0.321923
# radius_se                ...      0.618306       0.249152         0.607152
# texture_se               ...     -0.140583       0.559296        -0.141669
# perimeter_se             ...      0.601657       0.249408         0.621575
# area_se                  ...      0.818852       0.300221         0.808766
# smoothness_se            ...     -0.288060       0.025189        -0.276874
# compactness_se           ...      0.167289       0.168232         0.236493
# concavity_se             ...      0.264858       0.202682         0.321110
# concave_points_se        ...      0.351182       0.140922         0.390541
# symmetry_se              ...     -0.348702      -0.117374        -0.339094
# fractal_dimension_se     ...     -0.084643       0.046401        -0.033586
# radius_worst             ...      1.000000       0.339423         0.992543
# texture_worst            ...      0.339423       1.000000         0.344858
# perimeter_worst          ...      0.992543       0.344858         1.000000
# area_worst               ...      0.991383       0.344741         0.984582
# smoothness_worst         ...      0.198797       0.199153         0.221624
# compactness_worst        ...      0.489029       0.289316         0.555553
# concavity_worst          ...      0.627232       0.339824         0.676176
# concave_points_worst     ...      0.743442       0.315887         0.777380
# symmetry_worst           ...      0.238509       0.191856         0.261337
# fractal_dimension_worst  ...      0.088542       0.154855         0.141643
#
#                          area_worst  smoothness_worst  compactness_worst  \
# diagnosis                  0.773626          0.396847           0.533996
# radius_mean                0.957772          0.087209           0.416464
# texture_mean               0.317755          0.069886           0.216026
# perimeter_mean             0.959710          0.121237           0.460901
# area_mean                  0.971053          0.102255           0.400703
# smoothness_mean            0.125280          0.803945           0.432375
# compactness_mean           0.471562          0.588434           0.861979
# concavity_mean             0.701045          0.490384           0.772677
# concave_points_mean        0.790517          0.509263           0.692292
# symmetry_mean              0.128689          0.381236           0.339391
# fractal_dimension_mean    -0.351418          0.505745           0.345598
# radius_se                  0.635775          0.154293           0.236994
# texture_se                -0.121591         -0.026049          -0.120382
# perimeter_se               0.617565          0.139223           0.346653
# area_se                    0.841857          0.167888           0.325922
# smoothness_se             -0.248573          0.409537          -0.058653
# compactness_se             0.162762          0.193038           0.707305
# concavity_se               0.265809          0.218847           0.615389
# concave_points_se          0.339135          0.276047           0.498352
# symmetry_se               -0.327877         -0.114206          -0.194102
# fractal_dimension_se      -0.076252          0.209267           0.459512
# radius_worst               0.991383          0.198797           0.489029
# texture_worst              0.344741          0.199153           0.289316
# perimeter_worst            0.984582          0.221624           0.555553
# area_worst                 1.000000          0.209598           0.470541
# smoothness_worst           0.209598          1.000000           0.538113
# compactness_worst          0.470541          0.538113           1.000000
# concavity_worst            0.620125          0.513357           0.881096
# concave_points_worst       0.727666          0.572437           0.808226
# symmetry_worst             0.232574          0.501344           0.514601
# fractal_dimension_worst    0.087011          0.618424           0.755951
#
#                          concavity_worst  concave_points_worst  \
# diagnosis                       0.653300              0.726639
# radius_mean                     0.563240              0.682235
# texture_mean                    0.274070              0.238186
# perimeter_mean                  0.599672              0.712906
# area_mean                       0.559618              0.671695
# smoothness_mean                 0.372220              0.463910
# compactness_mean                0.780565              0.784528
# concavity_mean                  0.904941              0.861916
# concave_points_mean             0.794996              0.908179
# symmetry_mean                   0.292389              0.316389
# fractal_dimension_mean          0.162577              0.089302
# radius_se                       0.337137              0.424984
# texture_se                     -0.107413             -0.140466
# perimeter_se                    0.413572              0.474688
# area_se                         0.467633              0.562675
# smoothness_se                  -0.061050             -0.070554
# compactness_se                  0.594198              0.457711
# concavity_se                    0.722449              0.527705
# concave_points_se               0.543312              0.647279
# symmetry_se                    -0.237556             -0.285465
# fractal_dimension_se            0.339756              0.219289
# radius_worst                    0.627232              0.743442
# texture_worst                   0.339824              0.315887
# perimeter_worst                 0.676176              0.777380
# area_worst                      0.620125              0.727666
# smoothness_worst                0.513357              0.572437
# compactness_worst               0.881096              0.808226
# concavity_worst                 1.000000              0.875184
# concave_points_worst            0.875184              1.000000
# symmetry_worst                  0.445123              0.443940
# fractal_dimension_worst         0.595487              0.509315
#
#                          symmetry_worst  fractal_dimension_worst
# diagnosis                      0.347406                 0.290821
# radius_mean                    0.137655                -0.014583
# texture_mean                   0.076977                 0.060915
# perimeter_mean                 0.160178                 0.027877
# area_mean                      0.136700                -0.014754
# smoothness_mean                0.375969                 0.504310
# compactness_mean               0.424398                 0.656342
# concavity_mean                 0.363584                 0.470354
# concave_points_mean            0.360800                 0.381099
# symmetry_mean                  0.675715                 0.298244
# fractal_dimension_mean         0.254629                 0.725785
# radius_se                      0.096812                 0.023111
# texture_se                    -0.153698                -0.094223
# perimeter_se                   0.113375                 0.090374
# area_se                        0.130967                 0.021671
# smoothness_se                 -0.074991                 0.103602
# compactness_se                 0.158821                 0.506887
# concavity_se                   0.122369                 0.396337
# concave_points_se              0.059585                 0.256885
# symmetry_se                    0.206106                -0.109418
# fractal_dimension_se           0.069106                 0.659276
# radius_worst                   0.238509                 0.088542
# texture_worst                  0.191856                 0.154855
# perimeter_worst                0.261337                 0.141643
# area_worst                     0.232574                 0.087011
# smoothness_worst               0.501344                 0.618424
# compactness_worst              0.514601                 0.755951
# concavity_worst                0.445123                 0.595487
# concave_points_worst           0.443940                 0.509315
# symmetry_worst                 1.000000                 0.476495
# fractal_dimension_worst        0.476495                 1.000000
#
# [31 rows x 31 columns]

# %%
plt.figure(figsize = (20,16))

sns.heatmap(df_copy.corr(), annot = True, center = 0, fmt = ".2f", cmap="YlGnBu")
plt.title("Correlation matrix")
plt.show()

# %%
## Bar

plt.figure(figsize = (6, 4))

sns.histplot(data = df_copy, x = 'radius_mean', hue = 'diagnosis')
plt.show()

# %%
## Bar

plt.figure(figsize = (6, 4))

sns.histplot(data = df_copy, x = 'concave_points_worst', hue = 'diagnosis')
plt.show()

# %%
## Bar

plt.figure(figsize = (6, 6))

sns.histplot(data = df_copy, x = 'perimeter_mean', hue = 'diagnosis')
plt.show()

# %%
## Bar

plt.figure(figsize = (6, 4))

sns.histplot(data = df_copy, x = 'perimeter_worst', hue = 'diagnosis')
plt.show()

# %%
## Bar

plt.figure(figsize = (6, 4))

sns.scatterplot(data = df_copy, x = 'radius_mean', y = 'perimeter_mean', hue = 'diagnosis')
plt.show()

# %%
print(df_copy['diagnosis'].unique())
df_copy['diagnosis'].value_counts()
# Out:
# [1 0]
# diagnosis
# 0    300
# 1     98
# Name: count, dtype: int64

# %%
Malignant_vs_Benign = df_copy['diagnosis'].value_counts(normalize = True)
Malignant_vs_Benign
# Out:
# diagnosis
# 0    0.753769
# 1    0.246231
# Name: proportion, dtype: float64

# %%
### After Removing outliers, we next have to normalize all the values to around the range 0  to 1

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler


y = df_copy['diagnosis']
X = df_copy.drop(columns = ['diagnosis'])

scaler = MinMaxScaler()

X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay,  precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeClassifier

# %%
"""
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
##model selection

rf_clf = RandomForestClassifier(n_estimators = 100, random_state = 42)

cv_scores = cross_val_score(rf_clf, X_train, y_train, cv=5, scoring='accuracy')

## Training model using full data

rf_clf.fit(X_train, y_train)

print(f'Average Cross Validation Accuracy: {cv_scores.mean():.4f}')

pred_val = rf_clf.predict(X_test)

cm1 = confusion_matrix(y_test,pred_val)
print("Accuracy: ", accuracy_score(y_test,pred_val))
conf_matrix = sns.heatmap(cm1, annot=True,cmap=['lightblue','gray'])

print(conf_matrix)"""
# Out:
# '\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)\n##model selection\n\nrf_clf = RandomForestClassifier(n_estimators = 100, random_state = 42)\n\ncv_scores = cross_val_score(rf_clf, X_train, y_train, cv=5, scoring=\'accuracy\')\n\n## Training model using full data\n\nrf_clf.fit(X_train, y_train)\n\nprint(f\'Average Cross Validation Accuracy: {cv_scores.mean():.4f}\')\n\npred_val = rf_clf.predict(X_test)\n\ncm1 = confusion_matrix(y_test,pred_val)\nprint("Accuracy: ", accuracy_score(y_test,pred_val))\nconf_matrix = sns.heatmap(cm1, annot=True,cmap=[\'lightblue\',\'gray\'])\n\nprint(conf_matrix)'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)

# %%
X_train.shape
# Out:
# (278, 30)

# %% [markdown]
# ### HYperparameter tuning using GridSearchCV

# %%
# Hyperparameter tuning using GridSearchCV and Finding Best Paramters for Random Forest
param_grid_rf = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]

}

grid_search = GridSearchCV(RandomForestClassifier(random_state  = 42), param_grid = param_grid_rf, cv = 5, scoring = "accuracy")
grid_search.fit(X_train, y_train)

print(grid_search.best_params_)

best_model = grid_search.best_estimator_

y_prediction = best_model.predict(X_test)
# Out:
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}

# %%
print("After GridSearch RF Accuracy Score: ", accuracy_score(y_test, y_prediction))
print(X_train.shape)
# Out:
# After GridSearch RF Accuracy Score:  0.925
# (278, 30)

# %%
X_test.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
import shap
import matplotlib.pyplot as plt

# Assuming explainer and shap_values are already defined
feature_names = X_test.columns

for feature in feature_names:
    print(f"Plotting for: {feature}")
    shap.summary_plot(feature, shap_values.values, X_test, feature_names=X_test.columns)
    plt.show()
# Out:
# Plotting for: radius_mean
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 9
#       7 for feature in feature_names:
#       8     print(f"Plotting for: {feature}")
# ----> 9     shap.summary_plot(feature, shap_values.values, X_test, feature_names=feature_names)
#      10     plt.show()
#
# TypeError: summary_legacy() got multiple values for argument 'feature_names'

# %%
##For Decision we are  choosig the best paramaters directly using gridsearch

dec_clf = DecisionTreeClassifier(random_state = 42)

cv_scores_ = cross_val_score(dec_clf, X_train, y_train, cv=5, scoring='accuracy')

param_grid_dt = {
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]

}

grid_search_dec = GridSearchCV(DecisionTreeClassifier(random_state = 42), param_grid_dt, cv = 5, scoring = "accuracy")
grid_search_dec.fit(X_train, y_train)

print(grid_search_dec.best_params_)
best_model_dec = grid_search_dec.best_estimator_

y_prediction_dec = best_model_dec.predict(X_test)
# Out:
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10}

# %%
print("RandomeForest Accuracy Score: ", accuracy_score(y_test, y_prediction))
print("Decision Tree Accuracy Score: ", accuracy_score(y_test, y_prediction_dec))
# Out:
# RandomeForest Accuracy Score:  0.925
# Decision Tree Accuracy Score:  0.85

# %%
dec_conf = confusion_matrix(y_test,y_prediction_dec, normalize='true')

sns.heatmap(dec_conf, annot = True, cmap = ['gray', 'pink'])
print("Accuracy score:\n",accuracy_score(y_test, y_prediction_dec))
# Out:
# Accuracy score:
#  0.85

# %% [markdown]
# ###  Feature Selection using Randomforest

# %%
# Define features and target variable

# Train Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Get feature importance
feature_importances = pd.Series(rf.feature_importances_, index=X.columns)

imp_feat = pd.DataFrame({'features': X.columns, 'importance': rf.feature_importances_})
print(imp_feat.head())
#print(feature_importances[:10])
# Sort and plot
feature_importances.sort_values(ascending=False).plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.title('Feature Importance for Breast cancer data')
plt.show()
# Out:
#           features  importance
# 0      radius_mean    0.065493
# 1     texture_mean    0.014213
# 2   perimeter_mean    0.055861
# 3        area_mean    0.040397
# 4  smoothness_mean    0.006881

# %%
### USING TOP 10 SELECTED FEATURES TO TEST RANDOM FOREST MODEL AGAIN

# %%
from sklearn.ensemble import RandomForestClassifier


X_top = df_copy[['area_worst', 'concave_points_worst', 'concave_points_mean', 'radius_worst','radius_mean',  'perimeter_worst', 'perimeter_mean', "area_mean", 'concavity_mean', 'concavity_worst',  'area_se']]
y_top = df_copy['diagnosis']


param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]

}
random_f = RandomForestClassifier(n_estimators = 100,random_state  = 42)

X_train, X_test, y_train, y_test = train_test_split(X_top, y_top, test_size = 0.3, random_state = 42)

cross_val_s = cross_val_score(random_f, X_train, y_train, cv = 5, scoring = 'accuracy')
print(cross_val_s)
print("cross_val_s: ", cross_val_s.mean())

grid_search_best_rf = GridSearchCV(RandomForestClassifier(random_state  = 42), param_grid, cv = 5, scoring = "accuracy")
grid_search_best_rf.fit(X_train, y_train)


print(grid_search_best_rf.best_params_)

best_model_feature = grid_search_best_rf.best_estimator_
# Out:
# [0.91071429 0.92857143 0.94642857 0.94545455 1.        ]
# cross_val_s:  0.9462337662337662
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}

# %%
y_prediction_feature = best_model_feature.predict(X_test)

print("accuracy score after feature selection: ",accuracy_score(y_test, y_prediction_feature))
print(classification_report(y_test, y_prediction_feature))
# Out:
# accuracy score after feature selection:  0.8916666666666667
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        86
#            1       0.89      0.71      0.79        34
#
#     accuracy                           0.89       120
#    macro avg       0.89      0.84      0.86       120
# weighted avg       0.89      0.89      0.89       120

# %%
print("Accuracy_score after Feature selection", accuracy_score( y_test, y_prediction_feature))
# Out:
# Accuracy_score after Feature selection 0.8916666666666667

# %%
## This is to check feature contribution using shap before Standardization

explainer = shap.Explainer(best_model_feature, X_train)
shap_values = explainer(X_test, check_additivity=False)

feature_names = np.array(X_test.columns)

# Create the summary plot
shap.summary_plot(shap_values, X_test, feature_names=feature_names, show=False)
plt.show()
# Out:
# C:\Users\thall\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:950: UserWarning: The figure layout has changed to tight
#   pl.tight_layout()
# C:\Users\thall\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:624: UserWarning: The figure layout has changed to tight
#   pl.tight_layout(pad=0, w_pad=0, h_pad=0.0)

# %%
## Using Neural Networks to test classification of cancer types

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPool1D, Dropout
from keras.layers import Input, Flatten, Dense, BatchNormalization
from keras.utils import to_categorical

# %%
X_train.shape
# Out:
# (278, 30)

# %%
print(y_test.shape)
print(y_train.shape)
# Out:
# (120,)
# (278,)

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 42)

def binary_classification_model():
    ## Creating a model
    model = Sequential()
    model.add(Input(shape=(30, )))
    model.add(Dense(30, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(30, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    
    
    # compile model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model = binary_classification_model()
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, 
          verbose=2, callbacks=[early_stop])
# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
# Out:
# Epoch 1/100
# 7/7 - 4s - 626ms/step - accuracy: 0.4640 - loss: 0.7120 - val_accuracy: 0.5357 - val_loss: 0.6809
# Epoch 2/100
# 7/7 - 0s - 41ms/step - accuracy: 0.6622 - loss: 0.6500 - val_accuracy: 0.6250 - val_loss: 0.6683
# Epoch 3/100
# 7/7 - 0s - 35ms/step - accuracy: 0.7838 - loss: 0.6125 - val_accuracy: 0.6250 - val_loss: 0.6673
# Epoch 4/100
# 7/7 - 0s - 40ms/step - accuracy: 0.7748 - loss: 0.5917 - val_accuracy: 0.6250 - val_loss: 0.6734
# Epoch 5/100
# 7/7 - 0s - 32ms/step - accuracy: 0.7928 - loss: 0.5643 - val_accuracy: 0.6250 - val_loss: 0.6824
# Epoch 6/100
# 7/7 - 0s - 49ms/step - accuracy: 0.7928 - loss: 0.5410 - val_accuracy: 0.6250 - val_loss: 0.6792
# Epoch 7/100
# 7/7 - 0s - 31ms/step - accuracy: 0.7838 - loss: 0.5406 - val_accuracy: 0.6250 - val_loss: 0.6693
# Epoch 8/100
# 7/7 - 0s - 35ms/step - accuracy: 0.7838 - loss: 0.5253 - val_accuracy: 0.6250 - val_loss: 0.6507
# Epoch 9/100
# 7/7 - 0s - 29ms/step - accuracy: 0.8018 - loss: 0.4975 - val_accuracy: 0.6250 - val_loss: 0.6230
# Epoch 10/100
# 7/7 - 0s - 32ms/step - accuracy: 0.7883 - loss: 0.4860 - val_accuracy: 0.6250 - val_loss: 0.5979
# Epoch 11/100
# 7/7 - 0s - 41ms/step - accuracy: 0.7973 - loss: 0.4733 - val_accuracy: 0.7500 - val_loss: 0.5806
# Epoch 12/100
# 7/7 - 0s - 36ms/step - accuracy: 0.7973 - loss: 0.4923 - val_accuracy: 0.7500 - val_loss: 0.5738
# Epoch 13/100
# 7/7 - 0s - 35ms/step - accuracy: 0.8288 - loss: 0.4673 - val_accuracy: 0.7500 - val_loss: 0.5571
# Epoch 14/100
# 7/7 - 0s - 34ms/step - accuracy: 0.8333 - loss: 0.4253 - val_accuracy: 0.7679 - val_loss: 0.5509
# Epoch 15/100
# 7/7 - 0s - 35ms/step - accuracy: 0.8423 - loss: 0.4157 - val_accuracy: 0.7857 - val_loss: 0.5383
# Epoch 16/100
# 7/7 - 0s - 39ms/step - accuracy: 0.8559 - loss: 0.3956 - val_accuracy: 0.8214 - val_loss: 0.5201
# Epoch 17/100
# 7/7 - 1s - 72ms/step - accuracy: 0.8604 - loss: 0.3751 - val_accuracy: 0.8036 - val_loss: 0.5064
# Epoch 18/100
# 7/7 - 0s - 35ms/step - accuracy: 0.8604 - loss: 0.3891 - val_accuracy: 0.8036 - val_loss: 0.4894
# Epoch 19/100
# 7/7 - 0s - 36ms/step - accuracy: 0.8604 - loss: 0.3500 - val_accuracy: 0.8214 - val_loss: 0.4706
# Epoch 20/100
# 7/7 - 0s - 29ms/step - accuracy: 0.8739 - loss: 0.3710 - val_accuracy: 0.8393 - val_loss: 0.4528
# Epoch 21/100
# 7/7 - 0s - 52ms/step - accuracy: 0.8874 - loss: 0.3483 - val_accuracy: 0.8393 - val_loss: 0.4445
# Epoch 22/100
# 7/7 - 0s - 48ms/step - accuracy: 0.8649 - loss: 0.3410 - val_accuracy: 0.8393 - val_loss: 0.4436
# Epoch 23/100
# 7/7 - 0s - 38ms/step - accuracy: 0.8829 - loss: 0.3150 - val_accuracy: 0.8393 - val_loss: 0.4380
# Epoch 24/100
# 7/7 - 0s - 44ms/step - accuracy: 0.9144 - loss: 0.3040 - val_accuracy: 0.8393 - val_loss: 0.4191
# Epoch 25/100
# 7/7 - 0s - 59ms/step - accuracy: 0.8964 - loss: 0.2970 - val_accuracy: 0.8393 - val_loss: 0.4199
# Epoch 26/100
# 7/7 - 0s - 62ms/step - accuracy: 0.9054 - loss: 0.2836 - val_accuracy: 0.8393 - val_loss: 0.4057
# Epoch 27/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9009 - loss: 0.2691 - val_accuracy: 0.8571 - val_loss: 0.3760
# Epoch 28/100
# 7/7 - 0s - 30ms/step - accuracy: 0.9369 - loss: 0.2482 - val_accuracy: 0.8571 - val_loss: 0.3563
# Epoch 29/100
# 7/7 - 0s - 33ms/step - accuracy: 0.8964 - loss: 0.2880 - val_accuracy: 0.8571 - val_loss: 0.3753
# Epoch 30/100
# 7/7 - 0s - 31ms/step - accuracy: 0.9144 - loss: 0.2455 - val_accuracy: 0.8571 - val_loss: 0.3734
# Epoch 31/100
# 7/7 - 1s - 164ms/step - accuracy: 0.9324 - loss: 0.2281 - val_accuracy: 0.8571 - val_loss: 0.3556
# Epoch 32/100
# 7/7 - 1s - 119ms/step - accuracy: 0.9189 - loss: 0.2554 - val_accuracy: 0.8571 - val_loss: 0.3421
# Epoch 33/100
# 7/7 - 1s - 99ms/step - accuracy: 0.9234 - loss: 0.2456 - val_accuracy: 0.8571 - val_loss: 0.3156
# Epoch 34/100
# 7/7 - 1s - 91ms/step - accuracy: 0.9009 - loss: 0.2657 - val_accuracy: 0.8571 - val_loss: 0.3246
# Epoch 35/100
# 7/7 - 0s - 63ms/step - accuracy: 0.9054 - loss: 0.2526 - val_accuracy: 0.8571 - val_loss: 0.3394
# Epoch 36/100
# 7/7 - 0s - 36ms/step - accuracy: 0.9459 - loss: 0.2308 - val_accuracy: 0.8571 - val_loss: 0.3297
# Epoch 37/100
# 7/7 - 0s - 37ms/step - accuracy: 0.9189 - loss: 0.2384 - val_accuracy: 0.8571 - val_loss: 0.3269
# Epoch 38/100
# 7/7 - 0s - 30ms/step - accuracy: 0.9279 - loss: 0.2008 - val_accuracy: 0.8571 - val_loss: 0.3246
# Epoch 39/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9099 - loss: 0.2232 - val_accuracy: 0.8571 - val_loss: 0.3155
# Epoch 40/100
# 7/7 - 0s - 31ms/step - accuracy: 0.9189 - loss: 0.2283 - val_accuracy: 0.8571 - val_loss: 0.2996
# Epoch 41/100
# 7/7 - 0s - 32ms/step - accuracy: 0.9505 - loss: 0.2014 - val_accuracy: 0.8571 - val_loss: 0.3080
# Epoch 42/100
# 7/7 - 0s - 31ms/step - accuracy: 0.9099 - loss: 0.2208 - val_accuracy: 0.8571 - val_loss: 0.2831
# Epoch 43/100
# 7/7 - 0s - 31ms/step - accuracy: 0.9234 - loss: 0.2117 - val_accuracy: 0.8571 - val_loss: 0.2839
# Epoch 44/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9234 - loss: 0.2199 - val_accuracy: 0.8571 - val_loss: 0.2956
# Epoch 45/100
# 7/7 - 0s - 36ms/step - accuracy: 0.9234 - loss: 0.1930 - val_accuracy: 0.8571 - val_loss: 0.2680
# Epoch 46/100
# 7/7 - 0s - 34ms/step - accuracy: 0.9459 - loss: 0.1853 - val_accuracy: 0.8571 - val_loss: 0.2902
# Epoch 47/100
# 7/7 - 0s - 30ms/step - accuracy: 0.9054 - loss: 0.2115 - val_accuracy: 0.8571 - val_loss: 0.2882
# Epoch 48/100
# 7/7 - 0s - 38ms/step - accuracy: 0.9550 - loss: 0.1799 - val_accuracy: 0.8571 - val_loss: 0.2687
# Epoch 49/100
# 7/7 - 1s - 93ms/step - accuracy: 0.9640 - loss: 0.1704 - val_accuracy: 0.8571 - val_loss: 0.2586
# Epoch 50/100
# 7/7 - 0s - 34ms/step - accuracy: 0.9414 - loss: 0.1598 - val_accuracy: 0.8571 - val_loss: 0.2679
# Epoch 51/100
# 7/7 - 0s - 34ms/step - accuracy: 0.9369 - loss: 0.1603 - val_accuracy: 0.8571 - val_loss: 0.2491
# Epoch 52/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9505 - loss: 0.1608 - val_accuracy: 0.8750 - val_loss: 0.2285
# Epoch 53/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9324 - loss: 0.1689 - val_accuracy: 0.8571 - val_loss: 0.2395
# Epoch 54/100
# 7/7 - 0s - 32ms/step - accuracy: 0.9459 - loss: 0.1509 - val_accuracy: 0.8750 - val_loss: 0.2657
# Epoch 55/100
# 7/7 - 0s - 59ms/step - accuracy: 0.9414 - loss: 0.1644 - val_accuracy: 0.8750 - val_loss: 0.2264
# Epoch 56/100
# 7/7 - 0s - 36ms/step - accuracy: 0.9369 - loss: 0.1631 - val_accuracy: 0.8571 - val_loss: 0.2329
# Epoch 57/100
# 7/7 - 0s - 37ms/step - accuracy: 0.9505 - loss: 0.1420 - val_accuracy: 0.8571 - val_loss: 0.2293
# Epoch 58/100
# 7/7 - 0s - 36ms/step - accuracy: 0.9550 - loss: 0.1344 - val_accuracy: 0.8929 - val_loss: 0.2045
# Epoch 59/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9505 - loss: 0.1674 - val_accuracy: 0.8929 - val_loss: 0.2073
# Epoch 60/100
# 7/7 - 0s - 34ms/step - accuracy: 0.9505 - loss: 0.1405 - val_accuracy: 0.8750 - val_loss: 0.2388
# Epoch 61/100
# 7/7 - 0s - 35ms/step - accuracy: 0.9234 - loss: 0.1658 - val_accuracy: 0.8750 - val_loss: 0.2374
# Epoch 62/100
# 7/7 - 0s - 46ms/step - accuracy: 0.9685 - loss: 0.1431 - val_accuracy: 0.8929 - val_loss: 0.1963
# Epoch 63/100
# 7/7 - 0s - 39ms/step - accuracy: 0.9505 - loss: 0.1380 - val_accuracy: 0.8929 - val_loss: 0.2000
# Epoch 64/100
# 7/7 - 0s - 57ms/step - accuracy: 0.9595 - loss: 0.1370 - val_accuracy: 0.9107 - val_loss: 0.2064
# Epoch 65/100
# 7/7 - 0s - 49ms/step - accuracy: 0.9640 - loss: 0.1343 - val_accuracy: 0.9107 - val_loss: 0.1958
# Epoch 66/100
# 7/7 - 0s - 61ms/step - accuracy: 0.9595 - loss: 0.1180 - val_accuracy: 0.9107 - val_loss: 0.1998
# Epoch 67/100
# 7/7 - 0s - 44ms/step - accuracy: 0.9414 - loss: 0.1557 - val_accuracy: 0.9107 - val_loss: 0.1928
# Epoch 68/100
# 7/7 - 0s - 62ms/step - accuracy: 0.9595 - loss: 0.1318 - val_accuracy: 0.9107 - val_loss: 0.1845
# Epoch 69/100
# 7/7 - 1s - 87ms/step - accuracy: 0.9550 - loss: 0.1366 - val_accuracy: 0.8929 - val_loss: 0.1926
# Epoch 70/100
# 7/7 - 0s - 52ms/step - accuracy: 0.9550 - loss: 0.1248 - val_accuracy: 0.9107 - val_loss: 0.1811
# Epoch 71/100
# 7/7 - 1s - 90ms/step - accuracy: 0.9640 - loss: 0.1413 - val_accuracy: 0.8929 - val_loss: 0.2051
# Epoch 72/100
# 7/7 - 0s - 55ms/step - accuracy: 0.9595 - loss: 0.1120 - val_accuracy: 0.8929 - val_loss: 0.2093
# Epoch 73/100
# 7/7 - 1s - 76ms/step - accuracy: 0.9459 - loss: 0.1446 - val_accuracy: 0.8750 - val_loss: 0.2216
# Epoch 74/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9505 - loss: 0.1525 - val_accuracy: 0.9107 - val_loss: 0.1666
# Epoch 75/100
# 7/7 - 0s - 35ms/step - accuracy: 0.9640 - loss: 0.1306 - val_accuracy: 0.9464 - val_loss: 0.1409
# Epoch 76/100
# 7/7 - 0s - 38ms/step - accuracy: 0.9550 - loss: 0.1255 - val_accuracy: 0.9107 - val_loss: 0.1793
# Epoch 77/100
# 7/7 - 0s - 71ms/step - accuracy: 0.9505 - loss: 0.1610 - val_accuracy: 0.9107 - val_loss: 0.1745
# Epoch 78/100
# 7/7 - 0s - 54ms/step - accuracy: 0.9595 - loss: 0.1309 - val_accuracy: 0.9107 - val_loss: 0.1615
# Epoch 79/100
# 7/7 - 0s - 55ms/step - accuracy: 0.9459 - loss: 0.1493 - val_accuracy: 0.9286 - val_loss: 0.1442
# Epoch 80/100
# 7/7 - 0s - 46ms/step - accuracy: 0.9640 - loss: 0.0995 - val_accuracy: 0.9107 - val_loss: 0.1666
# Epoch 81/100
# 7/7 - 0s - 48ms/step - accuracy: 0.9640 - loss: 0.1082 - val_accuracy: 0.8929 - val_loss: 0.1791
# Epoch 82/100
# 7/7 - 0s - 44ms/step - accuracy: 0.9595 - loss: 0.1238 - val_accuracy: 0.9107 - val_loss: 0.1673
# Epoch 83/100
# 7/7 - 0s - 60ms/step - accuracy: 0.9685 - loss: 0.1249 - val_accuracy: 0.9286 - val_loss: 0.1441
# Epoch 84/100
# 7/7 - 1s - 95ms/step - accuracy: 0.9550 - loss: 0.1324 - val_accuracy: 0.9286 - val_loss: 0.1562
# Epoch 85/100
# 7/7 - 0s - 33ms/step - accuracy: 0.9505 - loss: 0.1446 - val_accuracy: 0.8929 - val_loss: 0.1793

# %%
print(f'Test loss: {loss:.3f}, Test accuracy: {accuracy:.3f}')
# Out:
# Test loss: 0.125, Test accuracy: 0.950
